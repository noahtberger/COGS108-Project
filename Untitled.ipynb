# %%
econ['year'] = econ['month'].dt.year
econ_yearly = econ.groupby('year')['economic_stress_index'].mean().reset_index()

# %%
merged_df = yearly_df.merge(econ_yearly, on = 'year')

# %%
corr_cols = ['party_score', 'romance_score', 'escape_score', 'economic_stress_index']
